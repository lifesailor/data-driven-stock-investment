# %% [markdown]
# # 1. Import Test

# %%
from pykrx import Krx

# %%
krx = Krx()

# %%
krx.get_tickers()
# Out:
# ['060310',
#  '095570',
#  '068400',
#  '006840',
#  '054620',
#  '265520',
#  '211270',
#  '027410',
#  '282330',
#  '138930',
#  '001460',
#  '001465',
#  '001040',
#  '079160',
#  '035760',
#  '000120',
#  '011150',
#  '011155',
#  '001045',
#  '097950',
#  '097955',
#  '051500',
#  '037560',
#  '058820',
#  '023460',
#  '065770',
#  '083660',
#  '000590',
#  '012030',
#  '306620',
#  '016610',
#  '005830',
#  '000990',
#  '000995',
#  '139130',
#  '068790',
#  '004840',
#  '241520',
#  '155660',
#  '069730',
#  '017940',
#  '245620',
#  '037370',
#  '079190',
#  '007700',
#  '130500',
#  '114090',
#  '032860',
#  '900290',
#  '078930',
#  '083450',
#  '006360',
#  '001250',
#  '007070',
#  '078935',
#  '028150',
#  '045890',
#  '078150',
#  '012630',
#  '039570',
#  '089470',
#  '294870',
#  '036640',
#  '082740',
#  '299170',
#  '254120',
#  '264850',
#  '276920',
#  '297570',
#  '003560',
#  '095340',
#  '099520',
#  '175330',
#  '950170',
#  '234080',
#  '067290',
# ...

# %% [markdown]
# # 2. API

# %%
df = krx.get_tickers()
print(df)
# Out:
# ['060310', '095570', '068400', '006840', '054620', '265520', '211270', '027410', '282330', '138930', '001460', '001465', '001040', '079160', '035760', '000120', '011150', '011155', '001045', '097950', '097955', '051500', '037560', '058820', '023460', '065770', '083660', '000590', '012030', '306620', '016610', '005830', '000990', '000995', '139130', '068790', '004840', '241520', '155660', '069730', '017940', '245620', '037370', '079190', '007700', '130500', '114090', '032860', '900290', '078930', '083450', '006360', '001250', '007070', '078935', '028150', '045890', '078150', '012630', '039570', '089470', '294870', '036640', '082740', '299170', '254120', '264850', '276920', '297570', '003560', '095340', '099520', '175330', '950170', '234080', '067290', '001060', '001067', '001065', '096760', '035900', '105560', '024120', '002380', '021320', '036670', '009070', '009440', '112190', '119650', '044180', '092220', '151860', '046440', '035600', '001390', '060720', '001940', '083470', '122450
# ...

# %%
df = krx.get_market_ohlcv("20170101", "20190224", "187790")
