# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/stock/folder/재무제표/045060.csv', engine='python', encoding='utf-8')

# %%
df.T
# Out:
#                      0           1           2              3           4  \
# index       연결_2016.12  연결_2017.12  연결_2018.12  연결_2019.12(E)  연결_2017.12
# 매출액(억원)           1431        1496        1507              0         370
# 영업이익(억원)            81          89          75              0          23
# 영업이익율(%)          5.64        5.92        4.99              -        6.32
# 당기순이익(억원)           52          59          63              0          14
# 순이익율(%)           3.65        3.93        4.17              -           0
# 자산총계(억원)          1205        1212        1287              -        1212
# 부채총계(억원)           646         603         543              -         603
# 자본총계(억원)           560         608         744              -         608
# 유보율(%)          814.19      898.65      771.08              -           0
# ROE              10.29        10.7        9.59              0           0
# PER              11.43        9.94        6.58              0           0
# ...
