# %% [markdown]
# # 1. Library

# %%
import urllib
import time

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %% [markdown]
# # 2. Crawl

# %%
stockCode = '119650' # 065450 빅텍

trendOfInvestorUrl = 'http://finance.naver.com/item/frgn.nhn?code=' + stockCode
trendOfInvestorHtml = urlopen(trendOfInvestorUrl)
trendOfInvestorSource = BeautifulSoup(trendOfInvestorHtml.read(), "html.parser")

trendOfInvestorPageNavigation = trendOfInvestorSource.find_all("table", align="center")
trendOfInvestorMaxPageSection = trendOfInvestorPageNavigation[0].find_all("td", class_="pgRR")
trendOfInvestorMaxPageNum = int(trendOfInvestorMaxPageSection[0].a.get('href')[-3:].replace('=', ''))

days = []
institutions = []
foreigners = []
foreigners_stocks = []
foreigners_ratios = []

print("전체: ", trendOfInvestorMaxPageNum)

for page in range(1, trendOfInvestorMaxPageNum + 1):
    print(page)
    
    url = 'http://finance.naver.com/item/frgn.nhn?code=' + stockCode + '&page=' + str(page)
    html = urlopen(url)
    source = BeautifulSoup(html.read(), "html.parser")
    dataSection = source.find("table", summary="외국인 기관 순매매 거래량에 관한표이며 날짜별로 정보를 제공합니다.")
    dayDataList = dataSection.find_all("tr")

    # day: 날짜
    # institutionPureDealing: 기관순매매
    # foreignerPureDealing: 외인순매매
    # ownedVolumeByForeigner: 외인보유 주식수
    # ownedRateByForeigner : 외인 보유율

    for i in range(3, len(dayDataList)):

        if(len(dayDataList[i].find_all("td", class_="tc")) != 0 and len(dayDataList[i].find_all("td", class_="num")) != 0):
            day = dayDataList[i].find_all("td", class_="tc")[0].text
            institutionPureDealing = dayDataList[i].find_all("td", class_="num")[4].text
            foreignerPureDealing = dayDataList[i].find_all("td", class_="num")[5].text
            ownedVolumeByForeigner = dayDataList[i].find_all("td", class_="num")[6].text
            ownedRateByForeigner = dayDataList[i].find_all("td", class_="num")[7].text
            
            days.append(day)
            institutions.append(institutionPureDealing)
            foreigners.append(foreignerPureDealing)
            foreigners_stocks.append(ownedVolumeByForeigner)
            foreigners_ratios.append(ownedRateByForeigner)
# Out:
# 전체:  112
# 1
# 2
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-2783db92a1f3>", line 24, in <module>
#     source = BeautifulSoup(html.read(), "html.parser")
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/bs4/__init__.py", line 278, in __init__
#     markup, from_encoding, exclude_encodings=exclude_encodings)):
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/bs4/builder/_htmlparser.py", line 237, in prepare_markup
#     exclude_encodings=exclude_encodings)
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/bs4/dammit.py", line 365, in __init__
#     for encoding in self.detector.encodings:
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/bs4/dammit.py", line 263, in encodings
#     self.chardet_encoding = chardet_dammit(self.markup)
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/bs4/dammit.py", line 33, in chardet_dammit
#     return chardet.detect(s)['encoding']
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/chardet/__init__.py", line 38, in detect
#     detector.feed(byte_str)
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/chardet/universaldetector.py", line 211, in feed
#     if prober.feed(byte_str) == ProbingState.FOUND_IT:
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/chardet/charsetgroupprober.py", line 71, in feed
#     state = prober.feed(byte_str)
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/chardet/mbcharsetprober.py", line 63, in feed
#     coding_state = self.coding_sm.next_state(byte_str[i])
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/chardet/codingstatemachine.py", line 69, in next_state
#     byte_class = self._model['class_table'][c]
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/anaconda3/envs/investment/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/anaconda3/envs/investment/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/anaconda3/envs/investment/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/anaconda3/envs/investment/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/anaconda3/envs/investment/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/anaconda3/envs/investment/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/anaconda3/envs/investment/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
df = pd.DataFrame({'날짜': days,
              '기관순매매': institutions,
              '외인순매매': foreigners,
              '외인보유량': foreigners_stocks,
              '외인보유비율': foreigners_ratios
             })

# %%
df
# Out:
#               날짜     기관순매매    외인순매매    외인보유량 외인보유비율
# 0     2019.02.28         0  -23,560   63,271  0.27%
# 1     2019.02.27         0  +12,071   86,831  0.36%
# 2     2019.02.26    -9,171  -35,074   67,760  0.28%
# 3     2019.02.25    -2,000  +18,364  102,834  0.43%
# 4     2019.02.22   +68,281   +6,750   84,470  0.35%
# 5     2019.02.21   +57,635     +436   77,720  0.33%
# 6     2019.02.20   +33,308  -25,402   77,284  0.32%
# 7     2019.02.19         0   -3,492  106,852  0.45%
# 8     2019.02.18         0   +9,826  110,344  0.46%
# 9     2019.02.15    -1,508   -1,869  100,518  0.42%
# 10    2019.02.14      -438   +9,681  102,387  0.43%
# 11    2019.02.13   +38,340  +22,512   92,706  0.39%
# 12    2019.02.12    +2,500   -2,250   70,194  0.29%
# 13    2019.02.11    +2,500  -32,863   72,444  0.30%
# 14    2019.02.08         0     +997  105,307  0.44%
# 15    2019.02.07         0  +17,875  104,310  0.44%
# 16    2019.02.01         0   +2,915  120,435  0.50%
# 17    2019.01.31         0  -18,358  117,520  0.49%
# 18    2019.01.30         0   +9,632  135,878  0.57%
# 19    2019.01.29         0   +2,864  126,246  0.53%
# 20    2019.01.28         0   -7,275  126,382  0.53%
# 21    2019.01.25    +5,000   +4,077  133,657  0.56%
# 22    2019.01.24         0  +18,483  129,580  0.54%
# 23    2019.01.23    -1,500  -25,140  111,275  0.47%
# 24    2019.01.22    +1,500  -26,729  136,415  0.57%
# 25    2019.01.21      +231   +3,318  163,144  0.68%
# 26    2019.01.18    +1,031  +34,912  163,924  0.69%
# 27    2019.01.17    +2,093  -53,982  127,012  0.53%
# 28    2019.01.16    -1,100   +7,254  175,994  0.74%
# 29    2019.01.15    +5,900  +15,496  168,740  0.71%
# ...          ...       ...      ...      ...    ...
# 1150  2014.06.20    -5,000        0        0  0.00%
# 1151  2014.06.19         0        0        0  0.00%
# 1152  2014.06.18         0        0        0  0.00%
# 1153  2014.06.17         0        0        0  0.00%
# 1154  2014.06.16    +7,459     -537        0  0.00%
# 1155  2014.06.13    -3,400        0      537  0.01%
# 1156  2014.06.12    +1,000     +537      537  0.01%
# 1157  2014.06.11         0        0        0  0.00%
# 1158  2014.06.10         0        0        0  0.00%
# 1159  2014.06.09         0     -714        0  0.00%
# 1160  2014.06.05         0     +714      714  0.01%
# 1161  2014.06.03    +3,118     -824        0  0.00%
# 1162  2014.06.02   -12,000   -1,830      824  0.01%
# 1163  2014.05.30    -5,710     -569    2,654  0.05%
# 1164  2014.05.29    -6,000        0    3,223  0.06%
# 1165  2014.05.28   -15,118   -1,000    3,223  0.06%
# 1166  2014.05.27         0        0    4,223  0.08%
# 1167  2014.05.26         0        0    4,223  0.08%
# 1168  2014.05.23    -3,030     +805    4,223  0.08%
# 1169  2014.05.22    +2,000     +705    3,418  0.06%
# 1170  2014.05.21         0   +2,713    2,713  0.05%
# 1171  2014.05.20         0        0        0  0.00%
# 1172  2014.05.19         0        0        0  0.00%
# 1173  2014.05.16         0   -7,079        0  0.00%
# 1174  2014.05.15         0   +3,296    7,079  0.13%
# 1175  2014.05.14         0   +3,783    3,783  0.07%
# 1176  2014.05.13   -12,719        0        0  0.00%
# 1177  2014.05.12   -11,785        0        0  0.00%
# 1178  2014.05.09   -46,683        0        0  0.00%
# 1179  2014.05.08  -234,689        0        0  0.00%
#
# [1180 rows x 5 columns]
